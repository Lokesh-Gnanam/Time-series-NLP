# %%
# !pip install scikit-learn
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: scikit-learn in c:\users\lokic\appdata\roaming\python\python313\site-packages (1.7.2)
# Requirement already satisfied: numpy>=1.22.0 in c:\users\lokic\appdata\roaming\python\python313\site-packages (from scikit-learn) (2.3.4)
# Requirement already satisfied: scipy>=1.8.0 in c:\users\lokic\appdata\roaming\python\python313\site-packages (from scikit-learn) (1.16.3)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\lokic\appdata\roaming\python\python313\site-packages (from scikit-learn) (1.5.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\lokic\appdata\roaming\python\python313\site-packages (from scikit-learn) (3.6.0)

# %%
import pandas as pd
import matplotlib.pyplot as plt
df = pd.read_csv(r"C:\Users\lokic\Documents\data\ML471_S1_Datafile_Concept.csv")

# %%
print(df.head())
# Out:
#          DATE  Consumption  Festivals/Special_events
# 0  01-01-1988     107.5052                         6
# 1  02-01-1988     105.6720                         1
# 2  03-01-1988      97.4502                         1
# 3  04-01-1988      92.4714                         1
# 4  05-01-1988      90.3151                         1

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 397 entries, 0 to 396
# Data columns (total 3 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   DATE                      397 non-null    object
#  1   Consumption               397 non-null    float64
#  2   Festivals/Special_events  397 non-null    int64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 9.4+ KB
# None

# %%
df['DateTime']=pd.to_datetime(df['DATE'])
df.set_index(df['DateTime'], inplace =True)

# %%
plt.figure(figsize=(10,6))
plt.plot(df['Consumption'], label='Electricity Consumption')

plt.title('Electricity Consumption Over Time')
plt.xlabel('Date')
plt.ylabel('Consumption')
plt.legend()

# %%
# !pip install statsmodels
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: statsmodels in c:\users\lokic\appdata\roaming\python\python313\site-packages (0.14.6)
# Requirement already satisfied: numpy<3,>=1.22.3 in c:\users\lokic\appdata\roaming\python\python313\site-packages (from statsmodels) (2.3.4)
# Requirement already satisfied: scipy!=1.9.2,>=1.8 in c:\users\lokic\appdata\roaming\python\python313\site-packages (from statsmodels) (1.16.3)
# Requirement already satisfied: pandas!=2.1.0,>=1.4 in c:\users\lokic\appdata\roaming\python\python313\site-packages (from statsmodels) (2.3.3)
# Requirement already satisfied: patsy>=0.5.6 in c:\users\lokic\appdata\roaming\python\python313\site-packages (from statsmodels) (1.0.2)
# Requirement already satisfied: packaging>=21.3 in c:\program files\python313\lib\site-packages (from statsmodels) (25.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\program files\python313\lib\site-packages (from pandas!=2.1.0,>=1.4->statsmodels) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\lokic\appdata\roaming\python\python313\site-packages (from pandas!=2.1.0,>=1.4->statsmodels) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\program files\python313\lib\site-packages (from pandas!=2.1.0,>=1.4->statsmodels) (2025.2)
# Requirement already satisfied: six>=1.5 in c:\program files\python313\lib\site-packages (from python-dateutil>=2.8.2->pandas!=2.1.0,>=1.4->statsmodels) (1.17.0)
